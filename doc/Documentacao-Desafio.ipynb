# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***Modelando Sistema Bancario em POO***

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# Objetivo Geral:
#
# Iniciar a modelagem do sistema bancário em POO. Adicionar classes para cliente e as operações bancárias: depósito e saque

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# Desafio:
#
# Atualizar a implementação do sistema bancário, para armazenar os dados de clientes e contas bancárias em objetos ao invés de dicionários.
#
# O código deve seguir o modelo de classes UML a seguir:

# %% [markdown]
# ![UML-Desafio-sistema_bancario.png](attachment:UML-Desafio-sistema_bancario.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ***Primeiro passo:***
#
# Criaremos as Classes 'Cliente' e seu herdeiro 'PessoaFisica':

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Cliente:
    pass

class PessoaFisica(Cliente):
    pass

# %% [markdown]
# --------------------------------------------------------------------------------------------------
